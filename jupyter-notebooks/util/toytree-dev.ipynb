# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext rpy2.ipython

import copy
import itertools
import MESS
import numpy as np
import pandas as pd
import random
import toytree

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)

# %%
data = MESS.Region("watdo")
data.set_param("J", 2000)
data.set_param("speciation_prob", 0.001)
data.set_param("generations", 0.25)
data.set_param("S_m", 10)
    
data.run(sims=1)
loc1 = data.islands["Loc1"]
print(loc1.extant_meta_toytree.write(tree_format=5))
tre = loc1.extant_meta_toytree
tre.draw()
for tip in tre.get_tip_labels():
    node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))

meta = loc1.extant_meta_toytree.write(tree_format=5)
local = loc1.extant_local_toytree.write(tree_format=5)
# Out:
#     Generating 1 simulation(s).
#   [####################] 100% 0.2435 ming Simulations    | 0:00:00 | t8.Loc1-14298 0.036702
# t8.Loc1-19446 0.031554
# t8.Loc1-46359 0.004641
# t8.Loc1-49645 0.001355
# t8.Loc1-50979 2.1e-05
# t8 2.1e-05
#   [####################] 100%  Finished 0 simulations
#  ((t10:0.153797,(t3:0.0156246,(t2:0.00253368,t7:0.00253368):0.0130909):0.138173):0.373219,((t9:0.295289,t1:0.295289):0.14068,((t6:0.095747,t5:0.138384):0.0222898,(t4:0.04363,(t8.Loc1-14298:0.036702,((t8.Loc1-19446:0.031554,(t8.Loc1-46359:0.004641,(t8.Loc1-49645:0.001355,(t8.Loc1-50979:2.1e-05,t8:2.1e-05):0.001334):0.003286):0.026913):0.000765,t8.Loc1-18681:0.008829):0.004383):0.057928):0.0744068):0.317932):0.0910475);
# t8.Loc1-18681	0.008829	0.02349000000000001
# t8	2.1e-05	0.0
# t8.Loc1-50979	2.1e-05	0.0
# t8.Loc1-49645	0.001355	0.0
# t8.Loc1-46359	0.004641	0.0
# t8.Loc1-19446	0.031554	0.0
# t8.Loc1-14298	0.036702	0.0
# t4	0.04362997871	0.051000000000000156
# ...

# %% [markdown]
# # Plotting and looking at node height/dist values

# %%
tre = data.islands["Loc1"].extant_meta_toytree
print(tre.write(tree_format=5))
print(tre)

for tip in tre.get_tip_labels():
    node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))
tre.draw()
#print(data.metacommunity.metacommunity_tree)
data.metacommunity.metacommunity_tree.write(tree_format=5)
data.metacommunity.metacommunity_tree.draw()
# Out:
# ((t10:0.153797,(t3:0.0156246,(t2:0.00253368,t7:0.00253368):0.0130909):0.138173):0.373219,((t9:0.295289,t1:0.295289):0.14068,((t6:0.095747,t5:0.138384):0.0222898,(t4:0.04363,(t8.Loc1-14298:0.036702,((t8.Loc1-19446:0.031554,(t8.Loc1-46359:0.004641,(t8.Loc1-49645:0.001355,(t8.Loc1-50979:2.1e-05,t8:2.1e-05):0.001334):0.003286):0.026913):0.000765,t8.Loc1-18681:0.008829):0.004383):0.057928):0.0744068):0.317932):0.0910475);
#
#       /-t10
#    /-|
#   |  |   /-t3
#   |   \-|
#   |     |   /-t2
#   |      \-|
# --|         \-t7
#   |
#   |      /-t9
#   |   /-|
#   |  |   \-t1
#   |  |
#    \-|      /-t6
#      |   /-|
#      |  |   \-t5
#       \-|
#         |   /-t4
#         |  |
#          \-|   /-t8.Loc1-14298
#            |  |
#            |  |      /-t8.Loc1-19446
#             \-|   /-|
#               |  |  |   /-t8.Loc1-46359
#               |  |   \-|
#               |  |     |   /-t8.Loc1-49645
#                \-|      \-|
#                  |        |   /-t8.Loc1-50979
# ...

# %%
## Draw with node labels
tre.draw(node_labels="idx", width=1000, height=1000)
# Out:
# (<toyplot.canvas.Canvas at 0x7fc32c30e2b0>,
#  <toyplot.coordinates.Cartesian at 0x7fc32ba289b0>)
# ...

# %% [markdown]
# ## Code to adjust branch lengths for local community
# Species created in the local community accumulate branch length, so
# here we make an adjustment to local clades to account for this.
#
# It doesn't work exactly right yet.

# %%
tre = data.metacommunity.metacommunity_tree.copy()
#d = tre.draw()

_root = tre.treenode.get_tree_root()
min_leaf, min_dist = _root.get_closest_leaf()
print("min leaf {} {}".format(min_leaf, min_dist))
max_leaf, max_dist = _root.get_farthest_leaf()

trim = max_dist - min_dist
print(trim)

clades = set([x.split("-")[0] for x in tre.get_tip_labels()])
print(clades)
for name in clades:
    if "." in name:
        idx = tre.get_mrca_idx_from_tip_labels(wildcard=name.split(".")[0])
        node = tre.treenode.search_nodes(idx=idx)[0]
        print(node.height)
        print(_root.get_distance(node))
        sis = node.get_sisters()[0]
        _root = node.get_tree_root()
        height = node.get_distance(node.get_farthest_leaf()[0])
        #node.dist = sis.dist - height
        print(node.height)
        print(_root.get_distance(node))
tre.draw()

for tip in tre.get_tip_labels():
    node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))
# Out:
# min leaf
# --t1 0.8456714346599999
# 0.054729000099999925
# {'t4.Loc1', 't7', 't10', 't2', 't9', 't6', 't2.Loc1', 't1', 't4', 't3', 't8', 't5'}
# 0.053259999999999974
# 0.8471404347600001
# 0.053259999999999974
# 0.8471404347600001
# 0.053259999999999974
# 0.8471404347600001
# 0.053259999999999974
# 0.8471404347600001
# t2	0.0	0.0
# t2.Loc1-54729	0.0	0.0
# t2.Loc1-54570	0.0	0.00015900000000002024
# t2.Loc1-54513	0.0	0.00021599999999999397
# t2.Loc1-53955	0.0	0.0007739999999999414
# t2.Loc1-53637	0.0	0.0010919999999999819
# t2.Loc1-52757	0.0	0.0019719999999999738
# t2.Loc1-52470	0.0	0.002259000000000011
# t2.Loc1-47253	0.0	0.007476000000000038
# t2.Loc1-46526	0.0	0.00820299999999996
# t2.Loc1-43620	0.0	0.011109000000000036
# t2.Loc1-43355	0.0	0.011373999999999995
# t2.Loc1-42870	0.0	0.011858999999999953
# t2.Loc1-42383	0.0	0.012345999999999968
# t2.Loc1-41679	0.0	0.013050000000000006
# t2.Loc1-40317	0.0	0.01441199999999998
# t2.Loc1-40203	0.0	0.014526000000000039
# ...

# %%
loc1.extant_local_toytree.draw()
loc1.extant_meta_toytree.draw()
# Out:
# (<toyplot.canvas.Canvas at 0x7fc32c394ac8>,
#  <toyplot.coordinates.Cartesian at 0x7fc32ba5ecc0>)
# ...

# %% [markdown]
# ## Get some topology summary stats

# %%
ltree = loc1.extant_local_toytree.write(tree_format=5)
mtree = loc1.extant_meta_toytree.write(tree_format=5)

# %%
# %%R -i meta -i local -o res
# library(phyloTop)
# mtree = read.tree(text=meta)
# ltree = read.tree(text=local)
# res = phyloTop(c(mtree, ltree), normalise=T)

# %%
res
# Out:
#    avgLadder  cherries  colless.phylo  ILnumber  maxHeight  pitchforks  \
# 1   0.285714       0.5       0.438095  0.571429   0.666667       0.375
# 2   0.750000       0.4       0.750000  0.750000   0.888889       0.300
#
#    sackin.phylo   stairs1   stairs2
# 1      0.637037  0.733333  0.480635
# 2      0.870370  0.777778  0.426984

# %% [markdown]
# ## Update the synthetic_community method to generate trees

# %%
dat, mtree, mtraits = MESS.util.synthetic_community(nspecies_meta=20)
ids = list(dat.index)
display(dat)
print(mtree)
print(mtraits)
# Out:
#           pi       dxy  abundance     trait  \
# l0  0.058702  0.003509        475  7.219463
# l1  0.028497  0.043698        379  0.524130
# l2  0.016041  0.093800        966  3.311077
# l3  0.086381  0.024901        810  1.964103
# l4  0.024740  0.053862        581  2.907353
# l5  0.065529  0.019858        534  6.539406
# l6  0.024792  0.027191         42  4.505628
# l7  0.013848  0.005154        502  0.158748
# l8  0.025356  0.001143        969  3.144914
# l9  0.088002  0.015374        633  9.041815
#
#                                                  tree
# l0  ((l7:0.666667,l6:0.666667):0.333333,((l5:0.333...
# l1  ((l7:0.666667,l6:0.666667):0.333333,((l5:0.333...
# l2                                       (l2:1,l9:1);
# l3                                       (l3:1,l8:1);
# l4  ((l7:0.666667,l6:0.666667):0.333333,((l5:0.333...
# l5  ((l7:0.666667,l6:0.666667):0.333333,((l5:0.333...
# l6  ((l7:0.666667,l6:0.666667):0.333333,((l5:0.333...
# ...

# %% [markdown]
# ## Update stats.calculate_sumstats() to get the tree stats as well

# %%
stat_dict = MESS.stats.calculate_sumstats(dat, metacommunity_traits=mtraits, metacommunity_tree=mtree, normalize_hills=True)
stat_dict
# Out:
#     S  abund_h1  abund_h2  abund_h3  abund_h4     pi_h1     pi_h2     pi_h3  \
# 0  10  0.945277  0.919757  0.900484  0.884545  0.916221  0.854488  0.815247
#
#       pi_h4   mean_pi    std_pi  skewness_pi  kurtosis_pi  median_pi  \
# 0  0.790513  0.043189  0.027247     0.587486    -1.279535   0.026927
#
#      iqr_pi    dxy_h1    dxy_h2    dxy_h3    dxy_h4  mean_dxys  std_dxys  \
# 0  0.039069  0.819279  0.726041  0.667108  0.627769   0.028849   0.02705
#
#    skewness_dxys  kurtosis_dxys  median_dxys  iqr_dxys  meta_avgLadder  \
# 0       1.206793       0.659916      0.02238  0.031863            0.12
#
#    meta_cherries  meta_colless.phylo  meta_ILnumber  meta_maxHeight  \
# 0       0.740741            0.150769           0.28        0.307692
#
#    meta_pitchforks  meta_sackin.phylo  meta_stairs1  meta_stairs2  \
# 0         0.444444           0.384615      0.576923      0.674359
#
#    local_avgLadder  local_cherries  local_colless.phylo  local_ILnumber  \
# ...

# %% [markdown]
# ## Paste tree stats into stat_dict

# %%
# res[0] is local, res[1] is meta
rdict = res.iloc[0].to_dict()
#stat_dict.to_dict() + rdict
rdict
# Out:
# {'avgLadder': 0.36666666666666664,
#  'cherries': 0.35294117647058826,
#  'colless.phylo': 0.5,
#  'ILnumber': 0.7333333333333333,
#  'maxHeight': 0.6875,
#  'pitchforks': 0.35294117647058826,
#  'sackin.phylo': 0.6710526315789473,
#  'stairs1': 0.8125,
#  'stairs2': 0.40910218253968256}

# %% [markdown]
# # Trash below here

# %%
data.metacommunity.trait_dict
#data.islands["Loc1"]._prepopulate()
loc1 = data.islands["Loc1"]
clades = loc1._get_clades()

## Dropping extinct species from the metacommunity tree
#all_sp = loc1.region.metacommunity.community["ids"]
#data.metacommunity.community
#for clade in clades.values():
#    print(clade)
#    drop = set(all_sp).difference(set(clade))
#    tre = loc1.region.metacommunity.metacommunity_tree.drop_tips(drop)
#    print(tre.write(tree_format=9))
#print(loc1.region.metacommunity.metacommunity_tree)

all_local_sp = [x for x in loc1.region.metacommunity.community["ids"] if loc1.NAME_SEPARATOR in x]
print(all_local_sp)
extinct_local_sp = set(all_local_sp).difference(set(loc1.local_community))
print(set(loc1.local_community))
print(extinct_local_sp)
loc1.extant_meta_toytree = loc1.region.metacommunity.metacommunity_tree.drop_tips(extinct_local_sp)

print(loc1.extant_meta_toytree.write(tree_format=5))
for node in loc1.extant_meta_toytree.treenode.traverse():
    try:
        #print("{} {}".format(node.name, node.is_leaf()))
        node.dist = loc1.local_info[node.name]["split_time"]/1e6
        print("{} {}".format(node.name, node.dist))
    except:
        pass

print(loc1.extant_meta_toytree.write(tree_format=5))

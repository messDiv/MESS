# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext rpy2.ipython

import copy
import itertools
import MESS
import numpy as np
import pandas as pd
import random
import toytree

from collections import Counter

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ## Paramaterize and run one short simulation to get some community data

# %%
data = MESS.Region("watdo")
data.set_param("J", 2500)
data.set_param("speciation_prob", 0.0005)
data.set_param("generations", 0.25)
data.set_param("S_m", 15)


data.run(sims=1)
loc1 = data.islands["Loc1"]
print(loc1.extant_meta_toytree.write(tree_format=5))
tre = loc1.extant_meta_toytree
tre.draw()
# Out:
#     Generating 1 simulation(s).
#   [####################] 100%  Finished 0 simulations    | 0:00:00 |
#  (((t11:0.860493,t2:0.860493):0.293685,((t14:0.307844,t5:0.307844):0.364599,(t13:0.453891,(t15:0.110627,(t6.Loc1-11988:0.047914,(t6.Loc1-17112:0.042663,(t6.Loc1-35723:0.024374,(t6.Loc1-36113:0.023046,t6:0.023046):0.001328):0.018289):0.005251):0.0627129):0.343264):0.218552):0.481735):0.185263,(t12:0.648371,((t10:0.162072,(t7:0.122944,t4:0.122944):0.0391285):0.156144,(t3:0.315414,(t9:0.296136,(t8:0.0679148,t1:0.0679148):0.228221):0.0192789):0.00280224):0.330154):0.69107);
# (<toyplot.canvas.Canvas at 0x7f2e8929b128>,
#  <toyplot.coordinates.Cartesian at 0x7f2e8930ef60>)
# ...

# %% [markdown]
# # Plotting and looking at node height/dist values

# %%
tre = data.islands["Loc1"].extant_meta_toytree
#print(tre.write(tree_format=5))

for tip in tre.get_tip_labels():
    node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))
tre.draw()
#print(data.metacommunity.metacommunity_tree)
#data.metacommunity.metacommunity_tree.write(tree_format=5)
data.metacommunity.metacommunity_tree.draw()
# Out:
# t1	0.067914785561	1.3799983378248726e-10
# t8	0.067914785561	1.3799983378248726e-10
# t9	0.29613559350000007	9.899991937345476e-11
# t3	0.31541445960000003	1.389999226830696e-10
# t4	0.12294373340999998	1.000000082740371e-10
# t7	0.12294373340999998	1.000000082740371e-10
# t10	0.16207221439999994	7.000000579182597e-11
# t12	0.6483710597000003	6.999956170261612e-11
# t6	0.023046000000000004	0.0
# t6.Loc1-36113	0.023046	0.0
# t6.Loc1-35723	0.024374000000000003	0.0
# t6.Loc1-17112	0.042663000000000006	0.0
# t6.Loc1-11988	0.047914000000000005	0.0
# t15	0.11062690196999997	0.0
# t13	0.4538913889	7.000000579182597e-11
# t5	0.3078438336000001	7.000000579182597e-11
# t14	0.3078438336000001	7.000000579182597e-11
# t2	0.8604934577000003	6.999956170261612e-11
# t11	0.8604934577000003	6.999956170261612e-11
# (<toyplot.canvas.Canvas at 0x7f2e8930e048>,
#  <toyplot.coordinates.Cartesian at 0x7f2e893495f8>)
# ...

# %%
## Draw with node labels
tre.draw(node_labels="idx", width=1000, height=1000)
nd = tre.treenode.get_leaves_by_name(name="t2")[0]
nd.up.idx
# Out:
# 153
# ...

# %% [markdown]
# ## Code to adjust branch lengths for local community
# Species created in the local community accumulate branch length, so
# here we make an adjustment to local clades to account for this.
#
# It doesn't work exactly right yet.

# %%
tre = data.metacommunity.metacommunity_tree.copy()
#tre = loc1.extant_meta_toytree.copy()
#d = tre.draw()

clades = set([x.split("-")[0] for x in tre.get_tip_labels()])
print(clades)
for name in clades:
    if "." in name:
        basename = name.split(".")[0]
        names = tre.treenode.get_leaves()
        names = [x.name for x in names if basename+"." in x.name or basename == x.name]
        # idx is the node id of the mrca of the local clade
        #idx = tre.get_mrca_idx_from_tip_labels(wildcard=name.split(".")[0])
        idx = tre.get_mrca_idx_from_tip_labels(names=names)
        print("{} {}".format(name, idx))
        node = tre.treenode.search_nodes(idx=idx)[0]
        print("{} {}".format(node.dist, node.height))
        node.dist = node.dist - node.height
        #node.height += 0.67
        print("{} {}".format(node.dist, node.height))
tre.draw(node_labels=False, tip_labels=True, width=1000, height=1000)
for tip in tre.get_tip_labels():
    node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))
# Out:
# {'t8', 't2', 't10', 't11', 't7', 't15', 't9', 't9.Loc1', 't13', 't4.Loc1', 't6', 't12', 't1', 't3', 't5', 't14', 't4'}
# t9.Loc1 96
# 0.5069500475 0.11399299997000023
# 0.3929570475299997 0.22798599994000046
# t4.Loc1 89
# 0.2908679357 0.16417600000000032
# 0.1266919356999997 0.27126000046000076
# t13	0.1919487905	4.3000003557835953e-10
# t11	0.1919487905	4.3000003557835953e-10
# t2	0.32817147629999993	4.3000003557835953e-10
# t5	1.0169119524999999	3.3000002730432243e-10
# t10	0.17754953823000003	0.0
# t7	0.17754953823000003	0.0
# t15	0.6561749898000001	3.000000248221113e-11
# t12	0.8104564588000001	3.000000248221113e-11
# t9	0.106893	0.06400100040000023
# t9.Loc1-50439	0.106893	0.06400100040000023
# t4	0.010242	0.10708400046000044
# t4.Loc1-57092	0.010242	0.10708400046000044
# t4.Loc1-51971	0.008697	0.11220500046000037
# t4.Loc1-50183	0.057885	0.11399300046000072
# t4.Loc1-49691	0.057965	0.11448500046000021
# t4.Loc1-49405	0.059895000000000004	0.11477100046000022
# ...

# %%
tre = data.metacommunity.metacommunity_tree.copy()

# Only local speciation will generate the '-' character in a tip label
clades = set([x.split(".")[0] for x in tre.get_tip_labels() if "-" in x])

# Get a dict of height:clade_name sorted by height from smallest to largest
d = {}
for c in clades:
    nd = tre.treenode.search_nodes(name=c)[0]
    d[nd.height] = c
heights = sorted(d.keys())
d = {x:d[x] for x in heights}
print(d)

for h, name in d.items():
    # Recalculate the max height now
    heights = []
    for tip in tre.get_tip_labels():
        tmp_node = tre.treenode.get_leaves_by_name(name=tip)[0]
        heights.append(round(tmp_node.height, 5))
#    counter = Counter(heights)
#    mode_height = counter.most_common(1)[0][0]
    max_height = max(heights)
    print("max height {}".format(max_height))
    
    name=name+".Loc1"
    # idx is the node id of the mrca of the local clade
    idx = tre.get_mrca_idx_from_tip_labels(wildcard=name)
    node = tre.treenode.search_nodes(idx=idx)[0]
    print("{} {} {}".format(name, idx, node.dist))
    node.dist -= max_height
    print("{} {} {}".format(name, idx, node.dist))

for tip in tre.get_tip_labels():
    tmp_node = tre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(tmp_node.name, tmp_node.dist, tmp_node.height))
tre.draw(node_labels="idx", width=1000, height=1000)
# Out:
# {0.0: 't5', 0.04278900002999997: 't13'}
# max height 0.06458
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-371-3365e0e10203> in <module>
#      26     name=name+".Loc1"
#      27     # idx is the node id of the mrca of the local clade
# ---> 28     idx = tre.get_mrca_idx_from_tip_labels(wildcard=name)
#      29     node = tre.treenode.search_nodes(idx=idx)[0]
#      30     print("{} {} {}".format(name, idx, node.dist))
#
# ~/Continuosity/toytree/toytree/Toytree.py in get_mrca_idx_from_tip_labels(self, names, wildcard, regex)
#     306         node = fuzzy_match_tipnames(
#     307             self, names, wildcard, regex, True, False)
# --> 308         return node.idx
#     309
#     310
#
# AttributeError: 'TreeNode' object has no attribute 'idx'

# %%
def fuzzy_match_tipnames(ttree, names, wildcard, regex, mrca=True, mono=True):
    """
    Used in multiple internal functions (e.g., .root()) and .drop_tips())
    to select an internal mrca node, or multiple tipnames, using fuzzy matching
    so that every name does not need to be written out by hand.
    name: verbose list
    wildcard: matching unique string
    regex: regex expression
    mrca: return mrca node of selected tipnames. 
    mono: raise error if selected tipnames are not monophyletic    
    """
    # require arguments
    if not any([names, wildcard, regex]):
        raise ToytreeError(
            "must enter an outgroup, wildcard selector, or regex pattern")

    # get list of **nodes** from {list, wildcard, or regex}
    tips = []
    if names:
        if isinstance(names, (str, int)):
            names = [names]
        notfound = [i for i in names if i not in ttree.get_tip_labels()]
        if any(notfound):
            raise ToytreeError(
                "Sample {} is not in the tree".format(notfound))
        tips = [i for i in ttree.treenode.get_leaves() if i.name in names]

    # use regex to match tipnames
    elif regex:
        tips = [
            i for i in ttree.treenode.get_leaves() if re.match(regex, i.name)
        ]               
        if not any(tips):
            raise ToytreeError("No Samples matched the regular expression")

    # use wildcard substring matching
    elif wildcard:
        tips = [i for i in ttree.treenode.get_leaves() if wildcard in i.name]
        if not any(tips):
            raise ToytreeError("No Samples matched the wildcard")

    # build list of **tipnames** from matched nodes
    if not tips:
        raise ToytreeError("no matching tipnames")       
    tipnames = [i.name for i in tips]

    # if a single tipname matched no need to check for monophyly
    if len(tips) == 1:
        if mrca:
            return tips[0]
        else:
            return tipnames

    # if multiple nodes matched, check if they're monophyletic
    mbool, mtype, mnames = (
        ttree.treenode.check_monophyly(
            tipnames, "name", ignore_missing=True)
    )

    # get mrca node
    node = ttree.treenode.get_common_ancestor(tips)

    # raise an error if required to be monophyletic but not
    if mono:
        if not mbool:
            raise ToytreeError(
                "Taxon list cannot be paraphyletic")

    # return tips or nodes
    if not mrca:
        return tipnames
    else:
        return node

wc = "t13"
nd = fuzzy_match_tipnames(tre, names="", wildcard=wc, regex="", mrca=False, mono=False)
print(nd)
tips = [i for i in tre.treenode.get_leaves() if wc in i.name]
node = tre.treenode.get_common_ancestor(tips)
node.name
nd = tre.treenode.get_common_ancestor(["t3", "t8"])
nd.name
tips[2].up.name
# Out:
# ['t13.Loc1-631', 't13.Loc1-827', 't13.Loc1-2417', 't13.Loc1-3608', 't13.Loc1-4128', 't13.Loc1-4155', 't13.Loc1-5398', 't13.Loc1-5466', 't13.Loc1-5887', 't13.Loc1-6663', 't13.Loc1-7231', 't13.Loc1-8108', 't13.Loc1-10466', 't13.Loc1-13519', 't13.Loc1-13844', 't13.Loc1-14274', 't13.Loc1-14784', 't13.Loc1-14787', 't13.Loc1-15440', 't13.Loc1-16023', 't13.Loc1-16069', 't13.Loc1-16987', 't13.Loc1-17389', 't13.Loc1-18383', 't13.Loc1-19484', 't13.Loc1-19754', 't13.Loc1-19766', 't13.Loc1-19964', 't13.Loc1-21506', 't13.Loc1-24336', 't13.Loc1-25002', 't13.Loc1-25302', 't13.Loc1-25318', 't13.Loc1-25601', 't13.Loc1-25899', 't13.Loc1-26830', 't13.Loc1-27620', 't13.Loc1-27749', 't13.Loc1-28917', 't13.Loc1-29017', 't13.Loc1-29435', 't13.Loc1-31534', 't13.Loc1-32277', 't13.Loc1-34319', 't13.Loc1-34551', 't13.Loc1-35131', 't13.Loc1-35982', 't13.Loc1-36809', 't13.Loc1-38249', 't13.Loc1-38392', 't13.Loc1-39905', 't13.Loc1-40304', 't13.Loc1-41482', 't13.Loc1-41829', 't13.Loc1-45317', 't13.Loc1-47043', 't1
# ...

# %% [markdown]
# ## Draw extant local and metacommunity trees

# %%
loc1.extant_local_toytree.draw()
loc1.extant_meta_toytree.draw()
# Out:
# (<toyplot.canvas.Canvas at 0x7f2ea44ea828>,
#  <toyplot.coordinates.Cartesian at 0x7f2ea44d55f8>)
# ...

# %%
#trash
ancestor = "t5"
sname = "t5.loc1-wat"
branch_length = 0.5
## Graft new species onto the metacommunity tree
anc_name = ancestor
anc_node = data.metacommunity.metacommunity_tree.treenode.get_leaves_by_name(name=anc_name)[0]
anc_node.dist = 0

if not anc_node.dist == 0:
    branch_length += anc_node.dist

sis = anc_node.get_sisters()[0]
## Create a new temporary baby tree for parent/child
new_tre = toytree.tree(newick="({}:{},{}:{}):0;".format(sname, branch_length, anc_name, branch_length))
## First add the new parent/child relationship, then drop the anc_node
new_node = sis.add_sister(sister=new_tre.treenode)
#new_node.dist = anc_node.dist
_ = sis.remove_sister(sister=anc_node)

# %%
data.metacommunity.metacommunity_tree.draw()
# Out:
# (<toyplot.canvas.Canvas at 0x7f2ea44a6fd0>,
#  <toyplot.coordinates.Cartesian at 0x7f2ea44ea710>)
# ...

# %% [markdown]
# ## Get some topology summary stats

# %%
ltree = loc1.extant_local_toytree.write(tree_format=5)
mtree = loc1.extant_meta_toytree.write(tree_format=5)

# %%
# %%R -i mtree -i ltree -o res
# library(phyloTop)
# mtree = read.tree(text=mtree)
# ltree = read.tree(text=ltree)
# res = phyloTop(c(mtree, ltree), normalise=T)

# %%
res
# Out:
#    avgLadder  cherries  colless.phylo  ILnumber  maxHeight  pitchforks  \
# 1   0.642857     0.375       0.504762  0.714286   0.733333       0.375
# 2   1.000000     0.200       1.000000  1.000000   1.000000       0.300
#
#    sackin.phylo   stairs1   stairs2
# 1      0.688889  0.800000  0.436679
# 2      1.000000  0.888889  0.314330

# %% [markdown]
# ## Update MESS.util.synthetic_community() method to generate trees
# Synthetic community data is not simulated under the model (time-consuming), but is
# rather just randomly generated (fast) with the right structure and with
# approximately realistic values.

# %%
dat, mtree, mtraits = MESS.util.synthetic_community(nspecies_meta=20)
display(dat)
print(mtree)
print(mtraits)
# Out:
#           pi       dxy  abundance     trait          tree
# l0  0.066967  0.071577        817  4.662156       (l0:1);
# l1  0.052322  0.040439        954  0.048377       (l1:1);
# l2  0.021899  0.075618         69  4.067418       (l2:1);
# l3  0.065470  0.030810        805  1.517249       (l3:1);
# l4  0.020187  0.084511         25  9.678465       (l4:1);
# l5  0.059854  0.041311        726  3.543804       (l5:1);
# l6  0.053472  0.078850         16  7.502724       (l6:1);
# l7  0.042899  0.053481        652  5.834041  (l7:1,l8:1);
# l8  0.040491  0.059879        479  4.151287  (l7:1,l8:1);
# l9  0.025124  0.091441        624  9.654801       (l9:1);
# ...

# %%
mtre = toytree.tree(mtree)
for tip in mtre.get_tip_labels():
    node = mtre.treenode.get_leaves_by_name(name=tip)[0]
    print("{}\t{}\t{}".format(node.name, node.dist, node.height))
# Out:
# l0	0.5	9.999999999177334e-07
# l1	0.5	9.999999999177334e-07
# l8	1.0	9.999999999177334e-07
# r5	0.285714	9.999999999177334e-07
# l6	1.0	9.999999999177334e-07
# r10	0.142857	9.999999999177334e-07
# r7	0.285714	9.999999999177334e-07
# r2	0.428571	9.999999999177334e-07
# r18	0.428571	9.999999999177334e-07
# r4	0.142857	9.999999999177334e-07
# r19	0.142857	9.999999999177334e-07
# r9	0.285714	9.999999999177334e-07
# l2	1.0	9.999999999177334e-07
# l3	1.0	9.999999999177334e-07
# r8	0.571429	0.0
# l4	1.0	0.0
# l7	1.0	0.0
# r6	0.571429	0.0
# r17	0.571429	0.0
# r11	0.571429	0.0
# r3	0.571429	0.0
# r1	0.714286	0.0
# l9	1.0	0.0
# l5	1.0	0.0
# r0	0.714286	0.0

# %% [markdown]
# ## Update stats.calculate_sumstats() to get the tree stats as well

# %%
stat_dict = MESS.stats.calculate_sumstats(dat, metacommunity_traits=mtraits, metacommunity_tree=mtree, normalize_hills=True)
stat_dict
# Out:
#     S  abund_h1  abund_h2  abund_h3  abund_h4     pi_h1     pi_h2     pi_h3  \
# 0  10  0.934174  0.907425  0.891095  0.879276  0.928295  0.908967  0.898875
#
#      pi_h4   mean_pi    std_pi  skewness_pi  kurtosis_pi  median_pi    iqr_pi  \
# 0  0.89234  0.063771  0.030796    -0.945448    -0.602847   0.076231  0.037879
#
#      dxy_h1    dxy_h2   dxy_h3    dxy_h4  mean_dxys  std_dxys  skewness_dxys  \
# 0  0.901288  0.868732  0.85073  0.838839   0.038636  0.022952      -0.334655
#
#    kurtosis_dxys  median_dxys  iqr_dxys  meta_avgLadder  meta_cherries  \
# 0      -1.334127     0.041954  0.039215        0.115385       0.428571
#
#    meta_colless.phylo  meta_ILnumber  meta_maxHeight  meta_pitchforks  \
# 0            0.253561       0.615385         0.37037         0.535714
#
#    meta_sackin.phylo  meta_stairs1  meta_stairs2  local_avgLadder  \
# 0           0.441975      0.777778      0.495699            0.375
#
# ...

# %% [markdown]
# # Trash below here

# %%
data.metacommunity.trait_dict
#data.islands["Loc1"]._prepopulate()
loc1 = data.islands["Loc1"]
clades = loc1._get_clades()

## Dropping extinct species from the metacommunity tree
#all_sp = loc1.region.metacommunity.community["ids"]
#data.metacommunity.community
#for clade in clades.values():
#    print(clade)
#    drop = set(all_sp).difference(set(clade))
#    tre = loc1.region.metacommunity.metacommunity_tree.drop_tips(drop)
#    print(tre.write(tree_format=9))
#print(loc1.region.metacommunity.metacommunity_tree)

all_local_sp = [x for x in loc1.region.metacommunity.community["ids"] if loc1.NAME_SEPARATOR in x]
print(all_local_sp)
extinct_local_sp = set(all_local_sp).difference(set(loc1.local_community))
print(set(loc1.local_community))
print(extinct_local_sp)
loc1.extant_meta_toytree = loc1.region.metacommunity.metacommunity_tree.drop_tips(extinct_local_sp)

print(loc1.extant_meta_toytree.write(tree_format=5))
for node in loc1.extant_meta_toytree.treenode.traverse():
    try:
        #print("{} {}".format(node.name, node.is_leaf()))
        node.dist = loc1.local_info[node.name]["split_time"]/1e6
        print("{} {}".format(node.name, node.dist))
    except:
        pass

print(loc1.extant_meta_toytree.write(tree_format=5))

# %%
node = mtre.treenode.get_leaves_by_name("r0")[0]
print("{} {}".format(node.dist, node.height))
node.dist -= 2
mtre.draw()
# Out:
# 2.7142859999999995 0.0
# (<toyplot.canvas.Canvas at 0x7f2e919f4c50>,
#  <toyplot.coordinates.Cartesian at 0x7f2e916f3358>)
# ...

# %%
tre = toytree.tree("https://eaton-lab.org/data/Cyathophora.tre")
# root and draw the tree (more details on this coming up...)
rtre = tre.root(wildcard="prz")
anc_node = rtre.treenode.get_leaves_by_name(name="33588_przewalskii")[0]
sis = anc_node.get_sisters()[0]
sis.name
new_node = sis.add_sister(dist=anc_node.dist)
#anc = new_node.add_child(anc_node)
new_node.add_child(name="new", dist=anc_node.dist)
new_node.add_child(name=anc_node.name, dist=anc_node.dist)
sis.remove_sister(sister=anc_node)
rtre.draw(width=500, height=400, node_labels=True, node_sizes=15, tip_labels_align=True);

print(sis.features)
tre.get_edge_values()
new_node.up.idx
# Out:
# {'name', 'support', 'height', 'dist', 'idx'}
# 23
# ...

# %%
tre
